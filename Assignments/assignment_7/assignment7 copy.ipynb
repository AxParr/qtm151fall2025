# %% [markdown]
# # Assignment 7

# %% [markdown]
# ## Submit your .ipynb file to Gradescope by Thursday, October 30th **by 10pm**

# %% [markdown]
# ##### Import the familiar libraries ``pandas``, ``numpy`` and ``matplotlib.pyplot``
#
# ##### In addition, we'll import a sublibrary from the ``statsmodels`` library. We'll use this in problems 4 and 5

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# for problems 4 and 5
import statsmodels.formula.api as smf

# %% [markdown]
# ##### Run the code chunk below to read the CSV file named `results.csv` in the `data` folder and print the first 5 rows of the dataset (using a quick alternative to `.iloc[:5,:]`). Browse the dataset.

# %%
df_results = pd.read_csv("data/results.csv")
print(df_results.head())

# Display the first 5 rows
first_rows = df_results.head(5)
print(first_rows)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
# Display the first 5 rows through iloc (For own purpose)
first_rows = df_results.iloc[:5, :]
print(first_rows)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
#Browsing the dataset
print(df_results.columns.values)
print()
# number of rows and columns of DataFrame
print(df_results.shape)
print()
n_rows, n_cols = df_results.shape
print("# of rows:", n_rows)
print("# of columns:", n_cols)
# Out:
# ['resultId' 'raceId' 'driverId' 'constructorId' 'number' 'grid' 'position'
#  'positionText' 'positionOrder' 'points' 'laps' 'time' 'milliseconds'
#  'fastestLap' 'rank' 'fastestLapTime' 'fastestLapSpeed' 'statusId']
#
# (25840, 18)
#
# # of rows: 25840
# # of columns: 18

# %% [markdown]
# ### (1)  Check Column Types and Data Cleaning
#
# - Use the attributes ``.dtypes`` to get the data types for each column of the DataFrame. Assign this to a variable named ``results_data_types``.
# - The 'milliseconds' column contains string values that should be numeric. Do the following:
#     - Replace all non-numeric values in the milliseconds column with ``np.nan``
#     - Add a new column to ``df_results`` called 'race_time_ms' by converting the 'milliseconds' column to a numeric data type using ``.to_numeric``

# %%
#Step 1: Personal Purposes
# print(results_data_types["milliseconds"].str.isnumeric())
non_numeric = df_results.query("  milliseconds.str.isnumeric() == False ")
print(non_numeric)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 5             6      18         6              3      8    13        6
# 6             7      18         7              5     14    17        7
# 7             8      18         8              6      1    15        8
# 8             9      18         9              2      4     2       \N
# 9            10      18        10              7     12    18       \N
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps time milliseconds fastestLap  \
# 5                6              6     3.0    57   \N           \N         50
# 6                7              7     2.0    55   \N           \N         22
# 7                8              8     1.0    53   \N           \N         20
# 8                R              9     0.0    47   \N           \N         15
# 9                R             10     0.0    43   \N           \N         23
# ...            ...            ...     ...   ...  ...          ...        ...
# 25835           16             16     0.0    57   \N           \N         39
# 25836           17             17     0.0    57   \N           \N         40
# 25837           18             18     0.0    55   \N           \N         42
# 25838           19             19     0.0    55   \N           \N         45
# 25839            R             20     0.0    27   \N           \N         24
#
#       rank fastestLapTime fastestLapSpeed  statusId
# 5       14       1:29.639         212.974        11
# 6       12       1:29.534         213.224         5
# 7        4       1:27.903         217.180         5
# 8        9       1:28.753         215.100         4
# 9       13       1:29.558         213.166         3
# ...    ...            ...             ...       ...
# 25835   12       1:29.833         211.632        11
# 25836   20       1:31.158         208.556        11
# 25837   11       1:29.788         211.738         9
# 25838   14       1:30.309         210.517       130
# 25839   17       1:30.579         209.889        47
#
# [18753 rows x 18 columns]

# %%
# Step 2: Personal Purposes
unique_non_numeric = pd.unique( non_numeric["milliseconds"] )
print(unique_non_numeric)
# Out:
# ['\\N']

# %%
# Assigning variable and getting data types for each column
results_data_types = df_results.dtypes

# Replacing all non-numeric values 
replace_vals = [np.nan]
df_results["milliseconds"] = df_results["milliseconds"].replace(unique_non_numeric, replace_vals)

non_numeric = df_results.query("  milliseconds.str.isnumeric() == False  ")
print(non_numeric)
# Out:
# Empty DataFrame
# Columns: [resultId, raceId, driverId, constructorId, number, grid, position, positionText, positionOrder, points, laps, time, milliseconds, fastestLap, rank, fastestLapTime, fastestLapSpeed, statusId]
# Index: []

# %%
print(df_results.dtypes)
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object

# %%
# converting the column to numeric
df_results["race_time_ms"] = pd.to_numeric(df_results["milliseconds"])
print(df_results["race_time_ms"].mean())
# Out:
# 6231870.430788768

# %% [markdown]
# ### (2) Recoding: Create categorical variables
#
# - The DataFrame has a column called 'position' which records whether a driver finished 1st, 2nd, 3rd, etc.
# - Create a new column called 'finish_category' that categorizes the race finish positions as follows:
#     - Positions 1-3: 'Podium'
#     - Positions 4-10: 'Points'
#     - Positions 11-20: 'Midfield'
#     - Positions >20: 'Backmarker'
#
# **Hint**: The shortest way to do this is to clean the data in the column and then use the ``.cut`` function in the ``pandas`` library. But this is not the only way to do it.

# %%
# finding non-numerics in position column
non_numeric = df_results.query("  position.str.isnumeric() == False ")
print(non_numeric)

#finding unique non-numeric values
unique_non_numeric = pd.unique( non_numeric["position"] )
print(unique_non_numeric)
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 8             9      18         9              2      4     2       \N
# 9            10      18        10              7     12    18       \N
# 10           11      18        11              8     18    19       \N
# 11           12      18        12              4      6    20       \N
# 12           13      18        13              6      2     4       \N
# ...         ...     ...       ...            ...    ...   ...      ...
# 25799     25805    1094       852            213     22    13       \N
# 25817     25823    1095       846              1      4     6       \N
# 25818     25824    1095       825            210     20     8       \N
# 25819     25825    1095       817              1      3    11       \N
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps time milliseconds fastestLap  \
# 8                R              9     0.0    47   \N          NaN         15
# 9                R             10     0.0    43   \N          NaN         23
# 10               R             11     0.0    32   \N          NaN         24
# 11               R             12     0.0    30   \N          NaN         20
# 12               R             13     0.0    29   \N          NaN         23
# ...            ...            ...     ...   ...  ...          ...        ...
# 25799            R             20     0.0    50   \N          NaN         48
# 25817            R             18     0.0    50   \N          NaN         48
# 25818            R             19     0.0     0   \N          NaN         \N
# 25819            R             20     0.0     0   \N          NaN         \N
# 25839            R             20     0.0    27   \N          NaN         24
#
#       rank fastestLapTime fastestLapSpeed  statusId  race_time_ms
# 8        9       1:28.753         215.100         4           NaN
# 9       13       1:29.558         213.166         3           NaN
# 10      15       1:30.892         210.038         7           NaN
# 11      16       1:31.384         208.907         8           NaN
# 12       6       1:28.175         216.510         5           NaN
# ...    ...            ...             ...       ...           ...
# 25799   18       1:23.403         185.777       130           NaN
# 25817   18       1:15.855         204.500         6           NaN
# 25818    0             \N              \N         4           NaN
# 25819    0             \N              \N         4           NaN
# 25839   17       1:30.579         209.889        47           NaN
#
# [10851 rows x 19 columns]
# ['\\N']

# %%
# Replacing all non-numeric values 
replace_vals = [np.nan]
df_results["position"] = df_results["position"].replace(unique_non_numeric, replace_vals)

non_numeric = df_results.query("  position.str.isnumeric() == False  ")
print(non_numeric)
# Out:
# Empty DataFrame
# Columns: [resultId, raceId, driverId, constructorId, number, grid, position, positionText, positionOrder, points, laps, time, milliseconds, fastestLap, rank, fastestLapTime, fastestLapSpeed, statusId, race_time_ms]
# Index: []

# %%
# converting the column to numeric
df_results["position"] = pd.to_numeric(df_results["position"])
print(df_results["position"].mean())
# Out:
# 7.942491160184135

# %%
# Cutting
pos_bins = [0, 3, 10, 20, float("inf")]

pos_labels = ["Podium", "Points", "Midfield", "Backmarker"]
df_results["finish_category"] = pd.cut(df_results["position"], 
                                bins = pos_bins,
                                right = True,
                                labels = pos_labels)
df_results.head(5)
# Out:
#    resultId  raceId  driverId  constructorId number  grid  position  \
# 0         1      18         1              1     22     1       1.0
# 1         2      18         2              2      3     5       2.0
# 2         3      18         3              3      7     7       3.0
# 3         4      18         4              4      5    11       4.0
# 4         5      18         5              1     23     3       5.0
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId  race_time_ms  \
# 0         39    2       1:27.452         218.300         1     5690616.0
# 1         41    3       1:27.739         217.586         1     5696094.0
# 2         41    5       1:28.090         216.719         1     5698779.0
# 3         58    7       1:28.603         215.464         1     5707797.0
# 4         43    1       1:27.418         218.385         1     5708630.0
#
#   finish_category
# 0          Podium
# 1          Podium
# 2          Podium
# 3          Points
# 4          Points

# %% [markdown]
# ### (3) Calculate Race Duration
# - Create a new column called 'race_duration_minutes' where we convert the race time in milliseconds to minutes by dividing each millisecond value by 60,000 (which equals $6 \times 10^4$). Equivalently, you can multiply each millisecond value by $6 \times 10^{-4}$
#
# - Each F1 car is associated with a "constructor", the entity which designs the chassis and engine of the car. Use ``.groupby`` to create a DataFrameGroupBy object, grouping by the "constructorID" column.
#
# - Compute the average race duration in minutes for each constructor. Then print out the constructorId's with the 5 fastest average times. (Both the constructorId and the corresponding average time in minutes should be visible)

# %%
# Race duration in minutes
# function to convert
def ms_to_min(ms):
    return ms/60000

ms = df_results["race_time_ms"]
min = ms.apply(ms_to_min)

df_results["race_duration_minutes"] = min

#print(df_results.head(5))

# %%
# grouping by constructor
constructor_group = df_results.groupby(by = "constructorId")
print(constructor_group)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x1485e6710>

# %%
# average race time by constructor
constructor_mean_times = constructor_group["race_duration_minutes"].mean()
print(constructor_mean_times)
# Out:
# constructorId
# 1       97.461541
# 2       94.119229
# 3       96.770410
# 4       95.154676
# 5      102.491413
#           ...
# 209    158.649761
# 210     98.769622
# 211     94.277482
# 213    101.922695
# 214     99.665660
# Name: race_duration_minutes, Length: 210, dtype: float64

# %% [markdown]
# ### (4) Linear Regression
#
# We return to the dataset of car features, in the file `features.csv`. We might guess that there is a simple linear relationship between the weight of a car and its miles per gallon (the heavier the car, the worse mileage it gets).
#
# In particular, we expect that these two variables are related by the approximate equality:
#
# $$ m_i \approx a\cdot w_i + b$$
#
# where $m_i$ is the mpg of car $i$, $w_i$ is the weight of car $i$, and $a$ (the slope) and $b$ (the y-intercept) are the coefficients of the linear model - which we need to determine. In this model, we say that "weight" is the **independent variable** and "mpg" is the **dependent variable**
#
#
# - Read in the carfeatures dataset, and assign it to a DataFrame.
#
# - At the top of the notebook, we imported the library ``statsmodels.formula.api`` with the nickname ``smf``. To construct the model, we will use the ``smf.ols`` (Ordinary Least Squares) function as follows:
# ```python
#         model = smf.ols(formula = ... , data = ...)
# ```
# - Replace the ellipses (...) in the arguments as follows:
#     - For formula, you should put the **string** "dependent_variable ~ independent_variable", where you should substitute the appropriate DataFrame column names for the two variables. (But keep the tilde (~) there)
#     - The data argument corresponds to the DataFrame you created when you read in the .csv file.
#
# - Compute a Pandas ``Series`` containing the computed coefficients $a$ and $b$ from the linear model. You can do this as follows:
# ```python
#         coeffs = model.fit().params
# ```
#
# This problem is continued in Question (5)

# %%
# your answer here
df_features = pd.read_csv("data/features.csv")
print(df_features.columns.values)

# creating model
model = smf.ols(formula = 'mpg ~ weight', data=df_features)

# Getting coefficients
coeffs = model.fit().params

print(coeffs)
# Out:
# ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration'
#  'vehicle_id']
# Intercept    46.317364
# weight       -0.007677
# dtype: float64

# %% [markdown]
# ### (5) Plotting Linear Regression Model
#
# In Question (4), you created a Pandas ``Series`` containing the coefficients of the linear model
#
# $$ m_i \approx a\cdot w_i + b$$
#
# - The elements of ``coeffs`` can be accessed as ``coeffs["Intercept"]`` (the y-intercept) and ``coeffs["weight"]`` (the slope). Define two separate floating-point number variables ``a`` and ``b`` corresponding to the model above.
#
# - Create a Pandas ``Series`` called ``predicted_mpg`` based on the formula:
# $$\hat{m}_i = a\cdot w_i + b$$
#
# - This means that each element of ``predicted_mpg`` is computed by multiplying ``a`` by the corresponding element in the "weight" column, and then adding ``b``. **Hint:** It's just like if you were working with Numpy arrays.
#
# - Using ``plt.scatter`` plot weight (on the x-axis) against mpg (on the y-axis).
#
# - Then using ``plt.plot`` (**not a scatter plot!**) plot weight (on the x-axis) against ``predicted_mpg`` (on the y-axis). They should appear on the same figure as long as you don't type ``plt.show`` in between.
#
# - Change the color of either the scatter plot or regular plot, so that they are easily distinguished from each other.
#
# - Label the axes, add a legend, and a title to your plot. For the legend, you might want to call the points in the scatter plot "data", and the linear fit line "best fit line".
#
# - Make sure your plots are output to the screen before submitting

# %%
# assigning coefficients
b = coeffs['Intercept']
a = coeffs['weight']

# calculating predicted mpg
predicted_mpg = b + a * df_features['weight']

# plotting
plt.scatter(df_features['weight'], df_features['mpg'], color='yellow', label='data')
plt.plot(df_features['weight'], predicted_mpg, color='purple', label='best fit line')
plt.xlabel("Weight")
plt.ylabel("MPG")

# Legend
plt.legend(labels = ["data", "best fit line"],
           title  = "Linear Regression Model")
plt.show()
